# %%
import pandas as pd
df=pd.read_csv('combined_shufled_data.csv') 
df.head()
# Out:
#    index                    id  ...     Y    category
# 0    249        politifact6652  ...  real  politifact
# 1   5524      gossipcop-938932  ...  real   gossipcop
# 2   1124  gossipcop-4955672121  ...  fake   gossipcop
# 3   7082      gossipcop-866973  ...  real   gossipcop
# 4   7628      gossipcop-897220  ...  real   gossipcop
#
# [5 rows x 7 columns]

# %% [markdown]
# # 新段落

# %%
newdf = df.groupby(['category','Y']).count()
newdf.head()
# Out:
#                  index    id  news_url  title  tweet_ids
# category   Y
# gossipcop  fake   1400  1400      1337   1400       1348
#            real   4385  4385      4382   4385       4108
# politifact fake    116   116       116    116        105
#            real    149   149       135    149         97

# %%
pd.core.frame.DataFrame
newdf.head()
# Out:
#                  index    id  news_url  title  tweet_ids
# category   Y
# gossipcop  fake   1400  1400      1337   1400       1348
#            real   4385  4385      4382   4385       4108
# politifact fake    116   116       116    116        105
#            real    149   149       135    149         97

# %%
import matplotlib.pyplot as plt

newdf.plot(kind='bar')
